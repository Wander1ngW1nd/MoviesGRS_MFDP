# %%
import pandas as pd
import numpy as np
import json
import re
import wikipedia
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
data_path = '../data_raw/'

# %%
movies_raw = pd.read_parquet(data_path +'movies.pq')  # инфа о фильмах -- названия и жанры 
links_raw = pd.read_parquet(data_path + 'links.pq')  # метчинг айдишников с другими датасетами
tmdb_data = pd.read_parquet(data_path + 'tmdb_data.pq')  # инфа о фильмах с tmdb

# %%
movies = movies_raw.merge(links_raw, on='movieId')[['movieId', 'tmdbId', 'title', 'genres']]
movies = movies.merge(tmdb_data, left_on='tmdbId', right_on='movie_id').drop(columns='movie_id')

# %%
movies.loc[:, 'genres_x'] = movies.genres_x.apply(lambda x: x.split('|'))
movies.loc[:, 'genres_y'] = movies.genres_y.apply(list)
movies['genres'] = (movies.genres_x + movies.genres_y).apply(set).apply(list)
movies.drop(columns=['genres_x', 'genres_y'], inplace=True)

# %%
def remove_no_genres(x):
    if ('(no genres listed)' in x) and len(x) > 1:
        return [el for el in x if el != '(no genres listed)']
    return x

def remove_foreign(x):
    if ('Foreign' in x):
        if len(x) > 1:
            return [el for el in x if el != 'Foreign']
        return ['(no genres listed)']
    return x
    
movies.loc[:, 'genres'] = movies.genres.apply(remove_no_genres).apply(remove_foreign)

# %%
# movies_wiki.loc[:, 'genres'] = movies_wiki.genres.apply(set)
def remove_duplicate_music(x):
    if ('Music' in x):
        tmp = [el for el in x if el != 'Music']
        if ('Musical' in x):
            return tmp
        else:
            return tmp + ['Musical']
    return x

def remove_duplicate_scifi(x):
    if ('Science Fiction' in x):
        tmp = [el for el in x if el != 'Science Fiction']
        if ('Sci-Fi' in x):
            return tmp
        else:
            return tmp + ['Sci-Fi']
    return x
    
movies.loc[:, 'genres'] = movies.genres.apply(remove_duplicate_music).apply(remove_duplicate_scifi)
np.unique(movies.genres.sum())
# Out:
# array(['(no genres listed)', 'Action', 'Adventure', 'Animation',
#        'Children', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family',
#        'Fantasy', 'Film-Noir', 'History', 'Horror', 'IMAX', 'Musical',
#        'Mystery', 'Romance', 'Sci-Fi', 'TV Movie', 'Thriller', 'War',
#        'Western'], dtype='<U18')

# %%
movies
# Out:
#       movieId    tmdbId                         title_x
# 0           1     862.0                Toy Story (1995)  \
# 1          10     710.0                GoldenEye (1995)
# 2          11    9087.0  American President, The (1995)
# 3          14   10858.0                    Nixon (1995)
# 4          15    1408.0         Cutthroat Island (1995)
# ...       ...       ...                             ...
# 4588   200562  248402.0              A Fine Step (2014)
# 4589   201050  206213.0            Zombie Hunter (2013)
# 4590   203797   24227.0          Excessive Force (1993)
# 4591   204288   51130.0              Open Secret (1948)
# 4592   206731   54702.0              Malevolence (2004)
#
#                      title_y  year
# 0                  Toy Story  1995  \
# 1                  GoldenEye  1995
# 2     The American President  1995
# 3                      Nixon  1995
# 4           Cutthroat Island  1995
# ...                      ...   ...
# 4588             A Fine Step  2014
# 4589           Zombie Hunter  2013
# 4590         Excessive Force  1993
# 4591             Open Secret  1948
# 4592             Malevolence  2004
#
#                                    production_countries  runtime    revenue
# 0                            [United States of America]     81.0  373554033  \
# 1            [United Kingdom, United States of America]    130.0  352194034
# 2                            [United States of America]    106.0  107879496
# 3                            [United States of America]    192.0   13681765
# 4     [France, Germany, Italy, United States of Amer...    119.0   10017322
# ...                                                 ...      ...        ...
# 4588                                                 []     90.0          0
# 4589                         [United States of America]     93.0          0
# 4590                         [United States of America]     87.0    1200000
# 4591                         [United States of America]     68.0          0
# 4592                         [United States of America]     90.0          0
#
#       popularity  vote_average  vote_count
# 0      73.640445           7.7        5269  \
# 1      59.824565           6.6        1174
# 2      11.056763           6.5         195
# 3       3.770161           7.1          71
# 4       7.029308           5.7         136
# ...          ...           ...         ...
# 4588    0.654340           4.1           7
# 4589    3.418372           3.5          34
# 4590    1.279106           4.5          10
# 4591    0.186401           7.0           2
# 4592    1.077321           4.9          14
#
#                                                    cast           director
# 0     [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...    [John Lasseter]  \
# 1     [Pierce Brosnan, Sean Bean, Izabella Scorupco,...  [Martin Campbell]
# 2     [Michael Douglas, Annette Bening, Michael J. F...       [Rob Reiner]
# 3     [Anthony Hopkins, Joan Allen, Powers Boothe, E...     [Oliver Stone]
# 4     [Geena Davis, Matthew Modine, Frank Langella, ...     [Renny Harlin]
# ...                                                 ...                ...
# 4588     [Luke Perry, Anna Claire Sneed, Leonor Varela]  [Jonathan Meyers]
# 4589  [Martin Copping, Danny Trejo, Clare Niederprue...       [Kevin King]
# 4590  [Thomas Ian Griffith, Lance Henriksen, James E...         [Jon Hess]
# 4591  [John Ireland, Jane Randolph, Sheldon Leonard,...   [John Reinhardt]
# 4592  [Samantha Dark, Heather Magee, Richard Glover,...      [Stevan Mena]
#
#                                                  genres
# 0     [Family, Comedy, Children, Animation, Adventur...
# 1                         [Action, Thriller, Adventure]
# 2                              [Romance, Drama, Comedy]
# 3                                      [History, Drama]
# 4                          [Action, Romance, Adventure]
# ...                                                 ...
# 4588                                            [Drama]
# 4589                 [Comedy, Action, Thriller, Sci-Fi]
# 4590                                           [Action]
# 4591                         [Mystery, Thriller, Crime]
# 4592                          [Thriller, Horror, Crime]
#
# [4593 rows x 14 columns]

# %%
def get_wikipedia_page_name(raw_name):
    names = wikipedia.search(raw_name)
    if len(names) == 0:
      return ''
    else:
      return names[0]

def get_movie_plot(page_name):
    try:
      try:
        movie_page_content = str(wikipedia.page(page_name, auto_suggest=False).content)
      except wikipedia.DisambiguationError as e:
        for option in e.options:
          if 'film' in option:
            movie_page_content = str(wikipedia.page(option, auto_suggest=False).content)
        return None
    except (wikipedia.PageError, KeyError):
      return None
    re_groups = re.search("Plot ==(.*?)=+ [A-Z]", str(movie_page_content).replace('\n', ''))
    if re_groups:
      return re_groups.group(1)
    else:
      return None

# %%
movies['wikipedia_page_name'] = movies['title_x'].progress_apply(lambda name: get_wikipedia_page_name(name))
movies['movie_plot'] = movies['wikipedia_page_name'].progress_apply(lambda page_name: get_movie_plot(page_name))
print(f'There are {movies["movie_plot"].isna().sum()} NaN movie plots')
movies
# Out:
#   0%|          | 0/4593 [00:00<?, ?it/s]
#   0%|          | 0/4593 [00:00<?, ?it/s]
# /home/danil/Desktop/MoviesGRS_MFDP/.venv/lib/python3.11/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /home/danil/Desktop/MoviesGRS_MFDP/.venv/lib/python3.11/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# There are 453 NaN movie plots
#       movieId    tmdbId                         title_x
# 0           1     862.0                Toy Story (1995)  \
# 1          10     710.0                GoldenEye (1995)
# 2          11    9087.0  American President, The (1995)
# 3          14   10858.0                    Nixon (1995)
# 4          15    1408.0         Cutthroat Island (1995)
# ...       ...       ...                             ...
# 4588   200562  248402.0              A Fine Step (2014)
# 4589   201050  206213.0            Zombie Hunter (2013)
# 4590   203797   24227.0          Excessive Force (1993)
# 4591   204288   51130.0              Open Secret (1948)
# 4592   206731   54702.0              Malevolence (2004)
#
#                      title_y  year
# 0                  Toy Story  1995  \
# 1                  GoldenEye  1995
# 2     The American President  1995
# 3                      Nixon  1995
# 4           Cutthroat Island  1995
# ...                      ...   ...
# 4588             A Fine Step  2014
# 4589           Zombie Hunter  2013
# 4590         Excessive Force  1993
# 4591             Open Secret  1948
# 4592             Malevolence  2004
#
#                                    production_countries  runtime    revenue
# 0                            [United States of America]     81.0  373554033  \
# 1            [United Kingdom, United States of America]    130.0  352194034
# 2                            [United States of America]    106.0  107879496
# 3                            [United States of America]    192.0   13681765
# 4     [France, Germany, Italy, United States of Amer...    119.0   10017322
# ...                                                 ...      ...        ...
# 4588                                                 []     90.0          0
# 4589                         [United States of America]     93.0          0
# 4590                         [United States of America]     87.0    1200000
# 4591                         [United States of America]     68.0          0
# 4592                         [United States of America]     90.0          0
#
#       popularity  vote_average  vote_count
# 0      73.640445           7.7        5269  \
# 1      59.824565           6.6        1174
# 2      11.056763           6.5         195
# 3       3.770161           7.1          71
# 4       7.029308           5.7         136
# ...          ...           ...         ...
# 4588    0.654340           4.1           7
# 4589    3.418372           3.5          34
# 4590    1.279106           4.5          10
# 4591    0.186401           7.0           2
# 4592    1.077321           4.9          14
#
#                                                    cast           director
# 0     [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...    [John Lasseter]  \
# 1     [Pierce Brosnan, Sean Bean, Izabella Scorupco,...  [Martin Campbell]
# 2     [Michael Douglas, Annette Bening, Michael J. F...       [Rob Reiner]
# 3     [Anthony Hopkins, Joan Allen, Powers Boothe, E...     [Oliver Stone]
# 4     [Geena Davis, Matthew Modine, Frank Langella, ...     [Renny Harlin]
# ...                                                 ...                ...
# 4588     [Luke Perry, Anna Claire Sneed, Leonor Varela]  [Jonathan Meyers]
# 4589  [Martin Copping, Danny Trejo, Clare Niederprue...       [Kevin King]
# 4590  [Thomas Ian Griffith, Lance Henriksen, James E...         [Jon Hess]
# 4591  [John Ireland, Jane Randolph, Sheldon Leonard,...   [John Reinhardt]
# 4592  [Samantha Dark, Heather Magee, Richard Glover,...      [Stevan Mena]
#
#                                                  genres
# 0     [Family, Comedy, Children, Animation, Adventur...  \
# 1                         [Action, Thriller, Adventure]
# 2                              [Romance, Drama, Comedy]
# 3                                      [History, Drama]
# 4                          [Action, Romance, Adventure]
# ...                                                 ...
# 4588                                            [Drama]
# 4589                 [Comedy, Action, Thriller, Sci-Fi]
# 4590                                           [Action]
# 4591                         [Mystery, Thriller, Crime]
# 4592                          [Thriller, Horror, Crime]
#
#          wikipedia_page_name
# 0                  Toy Story  \
# 1                  GoldenEye
# 2     The American President
# 3               Nixon (film)
# 4           Cutthroat Island
# ...                      ...
# 4588          A Fine Balance
# 4589    Zombie Hunter (film)
# 4590  Excessive Force (film)
# 4591             Open Secret
# 4592      Malevolence (film)
#
#                                              movie_plot
# 0     A group of living toys, who assume lifelessnes...
# 1     In 1986, MI6 agents James Bond and Alec Trevel...
# 2     Popular Democratic President Andrew Shepherd p...
# 3     In 1972, the White House Plumbers break into T...
# 4     In 1668 Jamaica, Morgan Adams having escaped a...
# ...                                                 ...
# 4588                                               None
# 4589  The film opens with a news report on "Natas", ...
# 4590  Detective Terry McCain (Thomas Ian Griffith) i...
# 4591  Newlyweds Paul Lester (Ireland) and his wife N...
# 4592  On May 14, 1989, six-year-old abductee Martin ...
#
# [4593 rows x 16 columns]

# %%
movies['wikipedia_page_name'] = movies.progress_apply(
    lambda row: get_wikipedia_page_name(row['title_y']) 
    if not row['movie_plot'] 
    else row['wikipedia_page_name'],
    axis=1
)
movies['movie_plot'] = movies.progress_apply(
    lambda row: get_movie_plot(row['wikipedia_page_name']) 
    if not row['movie_plot'] 
    else row['movie_plot'],
    axis=1
)
print(f'There are {movies["movie_plot"].isna().sum()} NaN movie plots')
movies
# Out:
#   0%|          | 0/4593 [00:00<?, ?it/s]

# %%
def get_new_wikipedia_page_name(raw_name):
    names = wikipedia.search(raw_name)
    if len(names) == 0:
      return ''
    else:
      for name in names:
        if '(film)' in name:
          return name
      return names[0]

movies['wikipedia_page_name'] = movies.progress_apply(
    lambda row: get_new_wikipedia_page_name(row['title_y']) 
    if not row['movie_plot'] 
    else row['wikipedia_page_name'],
    axis=1
)
movies['movie_plot'] = movies.progress_apply(
    lambda row: get_movie_plot(row['wikipedia_page_name']) 
    if not row['movie_plot'] 
    else row['movie_plot'],
    axis=1
)
print(f'There are {movies["movie_plot"].isna().sum()} NaN movie plots')
movies
# Out:
#   0%|          | 0/4593 [00:00<?, ?it/s]
#   0%|          | 0/4593 [00:00<?, ?it/s]
# /home/danil/Desktop/MoviesGRS_MFDP/.venv/lib/python3.11/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /home/danil/Desktop/MoviesGRS_MFDP/.venv/lib/python3.11/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# There are 264 NaN movie plots
#       movieId    tmdbId                         title_x
# 0           1     862.0                Toy Story (1995)  \
# 1          10     710.0                GoldenEye (1995)
# 2          11    9087.0  American President, The (1995)
# 3          14   10858.0                    Nixon (1995)
# 4          15    1408.0         Cutthroat Island (1995)
# ...       ...       ...                             ...
# 4588   200562  248402.0              A Fine Step (2014)
# 4589   201050  206213.0            Zombie Hunter (2013)
# 4590   203797   24227.0          Excessive Force (1993)
# 4591   204288   51130.0              Open Secret (1948)
# 4592   206731   54702.0              Malevolence (2004)
#
#                      title_y  year
# 0                  Toy Story  1995  \
# 1                  GoldenEye  1995
# 2     The American President  1995
# 3                      Nixon  1995
# 4           Cutthroat Island  1995
# ...                      ...   ...
# 4588             A Fine Step  2014
# 4589           Zombie Hunter  2013
# 4590         Excessive Force  1993
# 4591             Open Secret  1948
# 4592             Malevolence  2004
#
#                                    production_countries  runtime    revenue
# 0                            [United States of America]     81.0  373554033  \
# 1            [United Kingdom, United States of America]    130.0  352194034
# 2                            [United States of America]    106.0  107879496
# 3                            [United States of America]    192.0   13681765
# 4     [France, Germany, Italy, United States of Amer...    119.0   10017322
# ...                                                 ...      ...        ...
# 4588                                                 []     90.0          0
# 4589                         [United States of America]     93.0          0
# 4590                         [United States of America]     87.0    1200000
# 4591                         [United States of America]     68.0          0
# 4592                         [United States of America]     90.0          0
#
#       popularity  vote_average  vote_count
# 0      73.640445           7.7        5269  \
# 1      59.824565           6.6        1174
# 2      11.056763           6.5         195
# 3       3.770161           7.1          71
# 4       7.029308           5.7         136
# ...          ...           ...         ...
# 4588    0.654340           4.1           7
# 4589    3.418372           3.5          34
# 4590    1.279106           4.5          10
# 4591    0.186401           7.0           2
# 4592    1.077321           4.9          14
#
#                                                    cast           director
# 0     [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...    [John Lasseter]  \
# 1     [Pierce Brosnan, Sean Bean, Izabella Scorupco,...  [Martin Campbell]
# 2     [Michael Douglas, Annette Bening, Michael J. F...       [Rob Reiner]
# 3     [Anthony Hopkins, Joan Allen, Powers Boothe, E...     [Oliver Stone]
# 4     [Geena Davis, Matthew Modine, Frank Langella, ...     [Renny Harlin]
# ...                                                 ...                ...
# 4588     [Luke Perry, Anna Claire Sneed, Leonor Varela]  [Jonathan Meyers]
# 4589  [Martin Copping, Danny Trejo, Clare Niederprue...       [Kevin King]
# 4590  [Thomas Ian Griffith, Lance Henriksen, James E...         [Jon Hess]
# 4591  [John Ireland, Jane Randolph, Sheldon Leonard,...   [John Reinhardt]
# 4592  [Samantha Dark, Heather Magee, Richard Glover,...      [Stevan Mena]
#
#                                                  genres
# 0     [Family, Comedy, Children, Animation, Adventur...  \
# 1                         [Action, Thriller, Adventure]
# 2                              [Romance, Drama, Comedy]
# 3                                      [History, Drama]
# 4                          [Action, Romance, Adventure]
# ...                                                 ...
# 4588                                            [Drama]
# 4589                 [Comedy, Action, Thriller, Sci-Fi]
# 4590                                           [Action]
# 4591                         [Mystery, Thriller, Crime]
# 4592                          [Thriller, Horror, Crime]
#
#          wikipedia_page_name
# 0                  Toy Story  \
# 1                  GoldenEye
# 2     The American President
# 3               Nixon (film)
# 4           Cutthroat Island
# ...                      ...
# 4588              Luke Perry
# 4589    Zombie Hunter (film)
# 4590  Excessive Force (film)
# 4591             Open Secret
# 4592      Malevolence (film)
#
#                                              movie_plot
# 0     A group of living toys, who assume lifelessnes...
# 1     In 1986, MI6 agents James Bond and Alec Trevel...
# 2     Popular Democratic President Andrew Shepherd p...
# 3     In 1972, the White House Plumbers break into T...
# 4     In 1668 Jamaica, Morgan Adams having escaped a...
# ...                                                 ...
# 4588                                               None
# 4589  The film opens with a news report on "Natas", ...
# 4590  Detective Terry McCain (Thomas Ian Griffith) i...
# 4591  Newlyweds Paul Lester (Ireland) and his wife N...
# 4592  On May 14, 1989, six-year-old abductee Martin ...
#
# [4593 rows x 16 columns]

# %%
movies.dropna().to_parquet(data_path + 'movies_data.pq')

# %%
movies = pd.read_parquet(data_path + 'movies_wiki.pq')

# %%
movies = (
    movies
    .drop(columns=['title_x', 'wikipedia_page_name'])
    .rename(columns={
        'title_y': 'title', 
        'movieId': 'movielens_id', 
        'tmdbId': 'tmdb_id',
        'popularity': 'tmdb_popularity_score',
        'vote_average': 'tmdb_rating_avg',
        'vote_count': 'tmdb_votes_count'
    })
)
movies
# Out:
#       movielens_id   tmdb_id                        title  year
# 0                1     862.0                    Toy Story  1995  \
# 1               10     710.0                    GoldenEye  1995
# 2               11    9087.0       The American President  1995
# 3               14   10858.0                        Nixon  1995
# 4               15    1408.0             Cutthroat Island  1995
# ...            ...       ...                          ...   ...
# 4587        199952  367961.0  Savva. Heart of the Warrior  2015
# 4589        201050  206213.0                Zombie Hunter  2013
# 4590        203797   24227.0              Excessive Force  1993
# 4591        204288   51130.0                  Open Secret  1948
# 4592        206731   54702.0                  Malevolence  2004
#
#                                    production_countries  runtime    revenue
# 0                            [United States of America]     81.0  373554033  \
# 1            [United Kingdom, United States of America]    130.0  352194034
# 2                            [United States of America]    106.0  107879496
# 3                            [United States of America]    192.0   13681765
# 4     [France, Germany, Italy, United States of Amer...    119.0   10017322
# ...                                                 ...      ...        ...
# 4587                                           [Russia]     85.0          0
# 4589                         [United States of America]     93.0          0
# 4590                         [United States of America]     87.0    1200000
# 4591                         [United States of America]     68.0          0
# 4592                         [United States of America]     90.0          0
#
#       tmdb_popularity_score  tmdb_rating_avg  tmdb_votes_count
# 0                 73.640445              7.7              5269  \
# 1                 59.824565              6.6              1174
# 2                 11.056763              6.5               195
# 3                  3.770161              7.1                71
# 4                  7.029308              5.7               136
# ...                     ...              ...               ...
# 4587               2.625594              6.4                 7
# 4589               3.418372              3.5                34
# 4590               1.279106              4.5                10
# 4591               0.186401              7.0                 2
# 4592               1.077321              4.9                14
#
#                                                    cast           director
# 0     [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...    [John Lasseter]  \
# 1     [Pierce Brosnan, Sean Bean, Izabella Scorupco,...  [Martin Campbell]
# 2     [Michael Douglas, Annette Bening, Michael J. F...       [Rob Reiner]
# 3     [Anthony Hopkins, Joan Allen, Powers Boothe, E...     [Oliver Stone]
# 4     [Geena Davis, Matthew Modine, Frank Langella, ...     [Renny Harlin]
# ...                                                 ...                ...
# 4587  [Maksim Chukharyov, Konstantin Khabenskiy, Mik...    [Maksim Fadeev]
# 4589  [Martin Copping, Danny Trejo, Clare Niederprue...       [Kevin King]
# 4590  [Thomas Ian Griffith, Lance Henriksen, James E...         [Jon Hess]
# 4591  [John Ireland, Jane Randolph, Sheldon Leonard,...   [John Reinhardt]
# 4592  [Samantha Dark, Heather Magee, Richard Glover,...      [Stevan Mena]
#
#                                                  genres
# 0     [Family, Comedy, Children, Animation, Adventur...  \
# 1                         [Action, Thriller, Adventure]
# 2                              [Romance, Drama, Comedy]
# 3                                      [History, Drama]
# 4                          [Action, Romance, Adventure]
# ...                                                 ...
# 4587                    [Fantasy, Animation, Adventure]
# 4589                 [Comedy, Action, Thriller, Sci-Fi]
# 4590                                           [Action]
# 4591                         [Mystery, Thriller, Crime]
# 4592                          [Thriller, Horror, Crime]
#
#                                              movie_plot
# 0     A group of living toys, who assume lifelessnes...
# 1     In 1986, MI6 agents James Bond and Alec Trevel...
# 2     Popular Democratic President Andrew Shepherd p...
# 3     In 1972, the White House Plumbers break into T...
# 4     In 1668 Jamaica, Morgan Adams having escaped a...
# ...                                                 ...
# 4587  A mother tells her young son, Savva, a bed-tim...
# 4589  The film opens with a news report on "Natas", ...
# 4590  Detective Terry McCain (Thomas Ian Griffith) i...
# 4591  Newlyweds Paul Lester (Ireland) and his wife N...
# 4592  On May 14, 1989, six-year-old abductee Martin ...
#
# [4329 rows x 14 columns]

# %%
movies.to_parquet(data_path + 'movies_data.pq')

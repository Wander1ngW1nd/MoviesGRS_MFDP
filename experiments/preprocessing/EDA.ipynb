# %%
import pandas as pd
import numpy as np
import json
import re
import wikipedia
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
data_path = '../data_raw/'

# %%
movies_raw = pd.read_parquet(data_path +'movies.pq')  # инфа о фильмах -- названия и жанры 
ratings_raw = (
    pd.read_parquet(data_path + 'ratings.pq')
    .drop(columns='timestamp')
)  # инфа о рейтингах -- пользователи, рейтинги
tags_raw = (
    pd.read_parquet(data_path + 'tags.pq')
    .drop(columns='timestamp')
)  # тэги -- какой пользователь и какой тег поставил фильму
links_raw = pd.read_parquet(data_path + 'links.pq')  # метчинг айдишников с другими датасетами
tmdb_movies_raw = pd.read_parquet(data_path + 'tmdb_5000_movies.pq')  # инфа о фильмах с tmdb
tmdb_credits_raw = pd.read_parquet(data_path + 'tmdb_5000_credits.pq')  # инфа о создателях фильмов с tmdb
genome_data = pd.read_parquet(data_path + 'genome.pq')

# %% [markdown]
# ### TMDB preprocessing

# %%
tmdb_movies = tmdb_movies_raw[
    ['id', 'title', 'genres', 'release_date', 'production_countries', 'runtime', 'revenue', 'popularity', 'vote_average', 'vote_count']
]
tmdb_movies.loc[:, 'genres'] = tmdb_movies.genres.transform(lambda y: json.loads(y, object_hook=lambda x: x['name']))
tmdb_movies.loc[:, 'production_countries'] = tmdb_movies.production_countries.transform(lambda y: json.loads(y, object_hook=lambda x: x['name']))
tmdb_movies.loc[:, 'release_date'] = tmdb_movies.release_date.transform(lambda x: str(x).split('-')[0])
tmdb_movies = tmdb_movies.rename(columns={'id': 'movie_id', 'release_date': 'year'})
tmdb_movies
# Out:
#       movie_id                                     title
# 0        19995                                    Avatar  \
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                              genres  year
# 0     [Action, Adventure, Fantasy, Science Fiction]  2009  \
# 1                      [Adventure, Fantasy, Action]  2007
# 2                        [Action, Adventure, Crime]  2015
# 3                  [Action, Crime, Drama, Thriller]  2012
# 4              [Action, Adventure, Science Fiction]  2012
# ...                                             ...   ...
# 4798                      [Action, Crime, Thriller]  1992
# 4799                              [Comedy, Romance]  2011
# 4800             [Comedy, Drama, Romance, TV Movie]  2013
# 4801                                             []  2012
# 4802                                  [Documentary]  2005
#
#                             production_countries  runtime     revenue
# 0     [United States of America, United Kingdom]    162.0  2787965087  \
# 1                     [United States of America]    169.0   961000000
# 2     [United Kingdom, United States of America]    148.0   880674609
# 3                     [United States of America]    165.0  1084939099
# 4                     [United States of America]    132.0   284139100
# ...                                          ...      ...         ...
# 4798          [Mexico, United States of America]     81.0     2040920
# 4799                                          []     85.0           0
# 4800                  [United States of America]    120.0           0
# 4801           [United States of America, China]     98.0           0
# 4802                  [United States of America]     90.0           0
#
#       popularity  vote_average  vote_count
# 0     150.437577           7.2       11800
# 1     139.082615           6.9        4500
# 2     107.376788           6.3        4466
# 3     112.312950           7.6        9106
# 4      43.926995           6.1        2124
# ...          ...           ...         ...
# 4798   14.269792           6.6         238
# 4799    0.642552           5.9           5
# 4800    1.444476           7.0           6
# 4801    0.857008           5.7           7
# 4802    1.929883           6.3          16
#
# [4803 rows x 10 columns]

# %%
tmdb_credits = tmdb_credits_raw[['movie_id', 'cast', 'crew']]
tmdb_credits.loc[:, 'cast'] = tmdb_credits.cast.transform(lambda y: json.loads(y, object_hook=lambda x: x['name'])[:10])
tmdb_credits.loc[:, 'crew'] = tmdb_credits.crew.transform(lambda y: json.loads(y))
tmdb_credits.loc[:, 'crew'] = tmdb_credits.crew.transform(lambda x: [el for el in x if el['job'] == 'Director'])
tmdb_credits = tmdb_credits[tmdb_credits.crew.apply(len) >= 1]
tmdb_credits.loc[:, 'crew'] = tmdb_credits.crew.transform(lambda x: [el['name'] for el in x])
tmdb_credits = tmdb_credits.rename(columns={'crew': 'director'})
tmdb_credits
# Out:
#       movie_id                                               cast
# 0        19995  [Sam Worthington, Zoe Saldana, Sigourney Weave...  \
# 1          285  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2       206647  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3        49026  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4        49529  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
# ...        ...                                                ...
# 4798      9367  [Carlos Gallardo, Jaime de Hoyos, Peter Marqua...
# 4799     72766  [Edward Burns, Kerry Bishé, Marsha Dietlein, C...
# 4800    231617  [Eric Mabius, Kristin Booth, Crystal Lowe, Geo...
# 4801    126186  [Daniel Henney, Eliza Coupe, Bill Paxton, Alan...
# 4802     25975  [Drew Barrymore, Brian Herzlinger, Corey Feldm...
#
#                                       director
# 0                              [James Cameron]
# 1                             [Gore Verbinski]
# 2                                 [Sam Mendes]
# 3                          [Christopher Nolan]
# 4                             [Andrew Stanton]
# ...                                        ...
# 4798                        [Robert Rodriguez]
# 4799                            [Edward Burns]
# 4800                             [Scott Smith]
# 4801                             [Daniel Hsia]
# 4802  [Brian Herzlinger, Jon Gunn, Brett Winn]
#
# [4773 rows x 3 columns]

# %%
tmdb_data = tmdb_movies.merge(tmdb_credits, on='movie_id')
tmdb_data
# Out:
#       movie_id                                     title
# 0        19995                                    Avatar  \
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4768      9367                               El Mariachi
# 4769     72766                                 Newlyweds
# 4770    231617                 Signed, Sealed, Delivered
# 4771    126186                          Shanghai Calling
# 4772     25975                         My Date with Drew
#
#                                              genres  year
# 0     [Action, Adventure, Fantasy, Science Fiction]  2009  \
# 1                      [Adventure, Fantasy, Action]  2007
# 2                        [Action, Adventure, Crime]  2015
# 3                  [Action, Crime, Drama, Thriller]  2012
# 4              [Action, Adventure, Science Fiction]  2012
# ...                                             ...   ...
# 4768                      [Action, Crime, Thriller]  1992
# 4769                              [Comedy, Romance]  2011
# 4770             [Comedy, Drama, Romance, TV Movie]  2013
# 4771                                             []  2012
# 4772                                  [Documentary]  2005
#
#                             production_countries  runtime     revenue
# 0     [United States of America, United Kingdom]    162.0  2787965087  \
# 1                     [United States of America]    169.0   961000000
# 2     [United Kingdom, United States of America]    148.0   880674609
# 3                     [United States of America]    165.0  1084939099
# 4                     [United States of America]    132.0   284139100
# ...                                          ...      ...         ...
# 4768          [Mexico, United States of America]     81.0     2040920
# 4769                                          []     85.0           0
# 4770                  [United States of America]    120.0           0
# 4771           [United States of America, China]     98.0           0
# 4772                  [United States of America]     90.0           0
#
#       popularity  vote_average  vote_count
# 0     150.437577           7.2       11800  \
# 1     139.082615           6.9        4500
# 2     107.376788           6.3        4466
# 3     112.312950           7.6        9106
# 4      43.926995           6.1        2124
# ...          ...           ...         ...
# 4768   14.269792           6.6         238
# 4769    0.642552           5.9           5
# 4770    1.444476           7.0           6
# 4771    0.857008           5.7           7
# 4772    1.929883           6.3          16
#
#                                                    cast
# 0     [Sam Worthington, Zoe Saldana, Sigourney Weave...  \
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2     [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3     [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     [Taylor Kitsch, Lynn Collins, Samantha Morton,...
# ...                                                 ...
# 4768  [Carlos Gallardo, Jaime de Hoyos, Peter Marqua...
# 4769  [Edward Burns, Kerry Bishé, Marsha Dietlein, C...
# 4770  [Eric Mabius, Kristin Booth, Crystal Lowe, Geo...
# 4771  [Daniel Henney, Eliza Coupe, Bill Paxton, Alan...
# 4772  [Drew Barrymore, Brian Herzlinger, Corey Feldm...
#
#                                       director
# 0                              [James Cameron]
# 1                             [Gore Verbinski]
# 2                                 [Sam Mendes]
# 3                          [Christopher Nolan]
# 4                             [Andrew Stanton]
# ...                                        ...
# 4768                        [Robert Rodriguez]
# 4769                            [Edward Burns]
# 4770                             [Scott Smith]
# 4771                             [Daniel Hsia]
# 4772  [Brian Herzlinger, Jon Gunn, Brett Winn]
#
# [4773 rows x 12 columns]

# %%
# tmdb_data.to_parquet(data_path + 'tmdb_data.pq')

# %% [markdown]
# ### Wiki data

# %%
movies = movies_raw.merge(links_raw, on='movieId')[['movieId', 'tmdbId', 'title', 'genres']]
movies = movies.merge(tmdb_movies, left_on='tmdbId', right_on='movie_id')
movies
# Out:
#       movieId    tmdbId                         title_x
# 0           1     862.0                Toy Story (1995)  \
# 1          10     710.0                GoldenEye (1995)
# 2          11    9087.0  American President, The (1995)
# 3          14   10858.0                    Nixon (1995)
# 4          15    1408.0         Cutthroat Island (1995)
# ...       ...       ...                             ...
# 4597   200562  248402.0              A Fine Step (2014)
# 4598   201050  206213.0            Zombie Hunter (2013)
# 4599   203797   24227.0          Excessive Force (1993)
# 4600   204288   51130.0              Open Secret (1948)
# 4601   206731   54702.0              Malevolence (2004)
#
#                                          genres_x  movie_id
# 0     Adventure|Animation|Children|Comedy|Fantasy       862  \
# 1                       Action|Adventure|Thriller       710
# 2                            Comedy|Drama|Romance      9087
# 3                                           Drama     10858
# 4                        Action|Adventure|Romance      1408
# ...                                           ...       ...
# 4597                                        Drama    248402
# 4598                Action|Comedy|Sci-Fi|Thriller    206213
# 4599                                       Action     24227
# 4600                       Crime|Mystery|Thriller     51130
# 4601                        Crime|Horror|Thriller     54702
#
#                      title_y                                     genres_y
# 0                  Toy Story                  [Animation, Comedy, Family]  \
# 1                  GoldenEye                [Adventure, Action, Thriller]
# 2     The American President                     [Comedy, Drama, Romance]
# 3                      Nixon                             [History, Drama]
# 4           Cutthroat Island                          [Action, Adventure]
# ...                      ...                                          ...
# 4597             A Fine Step                                      [Drama]
# 4598           Zombie Hunter  [Comedy, Action, Science Fiction, Thriller]
# 4599         Excessive Force                                     [Action]
# 4600             Open Secret                   [Crime, Mystery, Thriller]
# 4601             Malevolence                    [Crime, Horror, Thriller]
#
#       year                               production_countries  runtime
# 0     1995                         [United States of America]     81.0  \
# 1     1995         [United Kingdom, United States of America]    130.0
# 2     1995                         [United States of America]    106.0
# 3     1995                         [United States of America]    192.0
# 4     1995  [France, Germany, Italy, United States of Amer...    119.0
# ...    ...                                                ...      ...
# 4597  2014                                                 []     90.0
# 4598  2013                         [United States of America]     93.0
# 4599  1993                         [United States of America]     87.0
# 4600  1948                         [United States of America]     68.0
# 4601  2004                         [United States of America]     90.0
#
#         revenue  popularity  vote_average  vote_count
# 0     373554033   73.640445           7.7        5269
# 1     352194034   59.824565           6.6        1174
# 2     107879496   11.056763           6.5         195
# 3      13681765    3.770161           7.1          71
# 4      10017322    7.029308           5.7         136
# ...         ...         ...           ...         ...
# 4597          0    0.654340           4.1           7
# 4598          0    3.418372           3.5          34
# 4599    1200000    1.279106           4.5          10
# 4600          0    0.186401           7.0           2
# 4601          0    1.077321           4.9          14
#
# [4602 rows x 14 columns]

# %%
def get_wikipedia_page_name(raw_name):
    names = wikipedia.search(raw_name)
    if len(names) == 0:
      return ''
    else:
      return names[0]

def get_movie_plot(page_name):
    try:
      try:
        movie_page_content = str(wikipedia.page(page_name, auto_suggest=False).content)
      except wikipedia.DisambiguationError as e:
        for option in e.options:
          if 'film' in option:
            movie_page_content = str(wikipedia.page(option, auto_suggest=False).content)
        return None
    except (wikipedia.PageError, KeyError):
      return None
    re_groups = re.search("Plot ==(.*?)=+ [A-Z]", str(movie_page_content).replace('\n', ''))
    if re_groups:
      return re_groups.group(1)
    else:
      return None

# %%
movies['wikipedia_page_name'] = movies['title_x'].progress_apply(lambda name: get_wikipedia_page_name(name))
movies['movie_plot'] = movies['wikipedia_page_name'].progress_apply(lambda page_name: get_movie_plot(page_name))
print(f'There are {movies["movie_plot"].isna().sum()} NaN movie plots')
movies

# %%
movies = movies.drop(columns='title_x').rename(columns={'title_y': 'title'})

# %%
movies.loc[:, 'genres_x'] = movies.genres_x.apply(lambda x: x.split('|'))
movies.loc[:, 'genres_y'] = movies.genres_y.apply(list)
movies['genres'] = (movies.genres_x + movies.genres_y).apply(set).apply(list)
movies.drop(columns=['genres_x', 'genres_y'], inplace=True)

# %%
def remove_no_genres(x):
    if ('(no genres listed)' in x) and len(x) > 1:
        return [el for el in x if el != '(no genres listed)']
    return x

def remove_foreign(x):
    if ('Foreign' in x):
        if len(x) > 1:
            return [el for el in x if el != 'Foreign']
        return ['(no genres listed)']
    return x
    
movies.loc[:, 'genres'] = movies.genres.apply(remove_no_genres).apply(remove_foreign)
movies[movies.genres.apply(str).str.contains('(no genres listed)')]
# Out:
# /tmp/ipykernel_4188/563145893.py:14: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   movies_wiki[movies_wiki.genres.apply(str).str.contains('(no genres listed)')]
#       movieId    tmdbId  movie_id
# 4247   132981  137955.0    137955  \
# 4349   141747  335874.0    335874
# 4394   146410  325140.0    325140
# 4461   153396  162396.0    162396
# 4486   158563  294550.0    294550
# 4535   163605   48382.0     48382
# 4585   190841  176074.0    176074
#
#                                                 title  year  runtime  revenue
# 4247                                        Crowsnest  2012     84.0        0  \
# 4349                                        Childless  2015     90.0        0
# 4394                           Hum To Mohabbat Karega  2000      0.0        0
# 4461                                     The Big Swap  1998      0.0        0
# 4486                     The Outrageous Sophie Tucker  2014     96.0        0
# 4535  The Book of Mormon Movie, Volume 1: The Journey  2003    120.0  1672730
# 4585                                     Reality Show  2015     92.0        0
#
#       popularity  vote_average  vote_count       wikipedia_page_name
# 4247    0.057564           4.8          12   Crowsnest Pass, Alberta  \
# 4349    0.243853           4.5           2             Childlessness
# 4394    0.001186           0.0           0    Hum To Mohabbat Karega
# 4461    0.627763           0.0           0              The Big Swap
# 4486    0.021419           0.0           0             Sophie Tucker
# 4535    0.031947           5.0           2  The Book of Mormon Movie
# 4585    0.472123           5.5           2        Reality television
#
#                                              movie_plot                genres
# 4247                                                     [(no genres listed)]
# 4349                                                     [(no genres listed)]
# 4394  Rajiv "Raju" Bhatnagar is a waiter in a popula...  [(no genres listed)]
# 4461  A group of friends meet and plan to swap partn...  [(no genres listed)]
# 4486                                                     [(no genres listed)]
# 4535  The film is based on the first two books of th...  [(no genres listed)]
# 4585                                                     [(no genres listed)]

# %%
# movies_wiki.loc[:, 'genres'] = movies_wiki.genres.apply(set)
def remove_duplicate_music(x):
    if ('Music' in x):
        tmp = [el for el in x if el != 'Music']
        if ('Musical' in x):
            return tmp
        else:
            return tmp + ['Musical']
    return x

def remove_duplicate_scifi(x):
    if ('Science Fiction' in x):
        tmp = [el for el in x if el != 'Science Fiction']
        if ('Sci-Fi' in x):
            return tmp
        else:
            return tmp + ['Sci-Fi']
    return x
    
movies.loc[:, 'genres'] = movies.genres.apply(remove_duplicate_music).apply(remove_duplicate_scifi)
np.unique(movies.genres.sum())
# Out:
# array(['(no genres listed)', 'Action', 'Adventure', 'Animation',
#        'Children', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Family',
#        'Fantasy', 'Film-Noir', 'History', 'Horror', 'IMAX', 'Musical',
#        'Mystery', 'Romance', 'Sci-Fi', 'TV Movie', 'Thriller', 'War',
#        'Western'], dtype='<U18')

# %%
production_country = tmdb_data[['movie_id', 'production_countries']]

# %%
movies = movies.merge(production_country, left_on='tmdbId', right_on='movie_id')

# %%
# movies_wiki.loc[:, 'movie_plot'] = movies_wiki.movie_plot.apply(lambda x: x if x != '' else None)
movies = movies.drop(columns=['wikipedia_page_name', 'movie_id_y']).rename(columns={'movie_id_x': 'movie_id'})
movies
# Out:
#       movieId    tmdbId  movie_id                   title  year  runtime
# 0           1     862.0       862               Toy Story  1995     81.0  \
# 1          10     710.0       710               GoldenEye  1995    130.0
# 2          11    9087.0      9087  The American President  1995    106.0
# 3          14   10858.0     10858                   Nixon  1995    192.0
# 4          15    1408.0      1408        Cutthroat Island  1995    119.0
# ...       ...       ...       ...                     ...   ...      ...
# 4588   200562  248402.0    248402             A Fine Step  2014     90.0
# 4589   201050  206213.0    206213           Zombie Hunter  2013     93.0
# 4590   203797   24227.0     24227         Excessive Force  1993     87.0
# 4591   204288   51130.0     51130             Open Secret  1948     68.0
# 4592   206731   54702.0     54702             Malevolence  2004     90.0
#
#         revenue  popularity  vote_average  vote_count
# 0     373554033   73.640445           7.7        5269  \
# 1     352194034   59.824565           6.6        1174
# 2     107879496   11.056763           6.5         195
# 3      13681765    3.770161           7.1          71
# 4      10017322    7.029308           5.7         136
# ...         ...         ...           ...         ...
# 4588          0    0.654340           4.1           7
# 4589          0    3.418372           3.5          34
# 4590    1200000    1.279106           4.5          10
# 4591          0    0.186401           7.0           2
# 4592          0    1.077321           4.9          14
#
#                                              movie_plot
# 0                                                  None  \
# 1     In 1986, MI6 agents James Bond and Alec Trevel...
# 2     Popular Democratic President Andrew Shepherd p...
# 3     In 1972, the White House Plumbers break into T...
# 4     In 1668 Jamaica, Morgan Adams having escaped a...
# ...                                                 ...
# 4588                                               None
# 4589  The film opens with a news report on "Natas", ...
# 4590  Detective Terry McCain (Thomas Ian Griffith) i...
# 4591  Newlyweds Paul Lester (Ireland) and his wife N...
# 4592  On May 14, 1989, six-year-old abductee Martin ...
#
#                                                  genres
# 0     [Fantasy, Adventure, Comedy, Children, Animati...  \
# 1                         [Adventure, Action, Thriller]
# 2                              [Comedy, Romance, Drama]
# 3                                      [History, Drama]
# 4                          [Adventure, Action, Romance]
# ...                                                 ...
# 4588                                            [Drama]
# 4589                 [Comedy, Action, Thriller, Sci-Fi]
# 4590                                           [Action]
# 4591                         [Crime, Mystery, Thriller]
# 4592                          [Crime, Horror, Thriller]
#
#                                    production_countries
# 0                            [United States of America]
# 1            [United Kingdom, United States of America]
# 2                            [United States of America]
# 3                            [United States of America]
# 4     [France, Germany, Italy, United States of Amer...
# ...                                                 ...
# 4588                                                 []
# 4589                         [United States of America]
# 4590                         [United States of America]
# 4591                         [United States of America]
# 4592                         [United States of America]
#
# [4593 rows x 13 columns]

# %%
movies = movies.merge(tmdb_data, left_on='movieId', right_on='movie_id')
movies
# Out:
#      movieId    tmdbId  movie_id_x                           title  year
# 0         11    9087.0        9087          The American President  1995  \
# 1         14   10858.0       10858                           Nixon  1995
# 2         16     524.0         524                          Casino  1995
# 3         18       5.0           5                      Four Rooms  1995
# 4         19    9273.0        9273  Ace Ventura: When Nature Calls  1995
# ..       ...       ...         ...                             ...   ...
# 318    89492   60308.0       60308                       Moneyball  2011
# 319   115210  228150.0      228150                            Fury  2014
# 320   116977  100042.0      100042              Dumb and Dumber To  2014
# 321   123553  252360.0      252360     In the Name of the King III  2013
# 322   127585  287524.0      287524                     Fear Clinic  2014
#
#      runtime    revenue  popularity  vote_average  vote_count
# 0      106.0  107879496   11.056763           6.5         195  \
# 1      192.0   13681765    3.770161           7.1          71
# 2      178.0  116112375   40.066880           7.8        1307
# 3       98.0    4300000   22.876230           6.5         530
# 4       90.0  212385533   34.391792           6.1        1099
# ..       ...        ...         ...           ...         ...
# 318    133.0  110206216   46.180421           7.0        1381
# 319    135.0  211817906  139.575085           7.4        3946
# 320    110.0  169837010   67.767785           5.4        1127
# 321     85.0          0    4.304341           3.3          19
# 322     95.0          0    1.859965           4.0          42
#
#                                             movie_plot
# 0    Popular Democratic President Andrew Shepherd p...  \
# 1    In 1972, the White House Plumbers break into T...
# 2    In 1973, sports handicapper and Mafia associat...
# 3    On New Year's Eve, bellhop Sam (Marc Lawrence)...
# 4    In the Himalayas, after a failed rescue missio...
# ..                                                 ...
# 318  Billy Beane, the Oakland Athletics general man...
# 319  In April of 1945, the Allies make their final ...
# 320  For twenty years a catatonic Lloyd Christmas h...
# 321                                               None
# 322  Sara (Fiona Dourif) is one of five people that...
#
#                                   genres
# 0               [Comedy, Romance, Drama]  \
# 1                       [History, Drama]
# 2                         [Crime, Drama]
# 3                        [Crime, Comedy]
# 4             [Crime, Adventure, Comedy]
# ..                                   ...
# 318                              [Drama]
# 319                 [War, Action, Drama]
# 320                             [Comedy]
# 321  [Fantasy, Adventure, Action, Drama]
# 322                             [Horror]
#
#                                   production_countries  movie_id_y
# 0                           [United States of America]          11  \
# 1                           [United States of America]          14
# 2                   [France, United States of America]          16
# 3                           [United States of America]          18
# 4                           [United States of America]          19
# ..                                                 ...         ...
# 318                         [United States of America]       89492
# 319  [United Kingdom, United States of America, China]      115210
# 320                         [United States of America]      116977
# 321                                 [Bulgaria, Canada]      123553
# 322                         [United States of America]      127585
#
#                                                   cast             director
# 0    [Mark Hamill, Harrison Ford, Carrie Fisher, Pe...       [George Lucas]
# 1    [Kevin Spacey, Annette Bening, Thora Birch, We...         [Sam Mendes]
# 2    [Björk, Catherine Deneuve, David Morse, Peter ...     [Lars von Trier]
# 3    [Bruce Willis, Gary Oldman, Ian Holm, Milla Jo...         [Luc Besson]
# 4    [Brigitte Helm, Alfred Abel, Gustav Fröhlich, ...         [Fritz Lang]
# ..                                                 ...                  ...
# 318  [Paul Rudd, Leslie Mann, Jason Segel, Maude Ap...        [Judd Apatow]
# 319  [Ross Noble, Tommy Knight, Gemma-Leah Devereux...      [Conor McMahon]
# 320  [Charlie Sheen, Wayne Brady, Hilary Duff, Eva ...  [Lawrence Kasanoff]
# 321  [Lily Collins, Jamie Campbell Bower, Kevin Zeg...       [Harald Zwart]
# 322  [Hugh Jackman, James McAvoy, Michael Fassbende...       [Bryan Singer]
#
# [323 rows x 16 columns]

# %%
# movies.to_parquet(data_path + 'movies_data.pq')

# %% [markdown]
# ### Сводим фильмы с тегами

# %%
tag_relevance_threshold = 0.3

# %%
movies = movies_raw.merge(genome, on='movieId')
movies = movies[movies.relevance > tag_relevance_threshold]
movies
# Out:
#           movieId                                title
# 10              1                     Toy Story (1995)  \
# 18              1                     Toy Story (1995)
# 19              1                     Toy Story (1995)
# 20              1                     Toy Story (1995)
# 28              1                     Toy Story (1995)
# ...           ...                                  ...
# 15584410   206499  Between Two Ferns: The Movie (2019)
# 15584420   206499  Between Two Ferns: The Movie (2019)
# 15584422   206499  Between Two Ferns: The Movie (2019)
# 15584423   206499  Between Two Ferns: The Movie (2019)
# 15584435   206499  Between Two Ferns: The Movie (2019)
#
#                                                genres                 tag
# 10        Adventure|Animation|Children|Comedy|Fantasy                  3d  \
# 18        Adventure|Animation|Children|Comedy|Fantasy              action
# 19        Adventure|Animation|Children|Comedy|Fantasy       action packed
# 20        Adventure|Animation|Children|Comedy|Fantasy          adaptation
# 28        Adventure|Animation|Children|Comedy|Fantasy           adventure
# ...                                               ...                 ...
# 15584410                                       Comedy  visually appealing
# 15584420                                       Comedy             weapons
# 15584422                                       Comedy                weed
# 15584423                                       Comedy               weird
# 15584435                                       Comedy               women
#
#           relevance
# 10          0.58025
# 18          0.66250
# 19          0.30075
# 20          0.31675
# 28          0.89375
# ...             ...
# 15584410    0.38400
# 15584420    0.43075
# 15584422    0.35375
# 15584423    0.36950
# 15584435    0.32850
#
# [1545390 rows x 5 columns]

# %%
all_tags = pd.Series(movies.tag.unique())
all_tags.shape
# Out:
# (1128,)

# %%
stemmer = SnowballStemmer('english')
stemmed_tags = movies.tag.apply(stemmer.stem)
unique_stammed = stemmed_tags.unique()
unique_stammed.shape
# Out:
# (1078,)

# %%
# nltk.download('averaged_perceptron_tagger')
tags_with_pos = all_tags.apply(str.split).apply(nltk.pos_tag)

# %% [markdown]
# Получается много пересекающихся тегов, в том числе потому, что многие похожие по смыслу теги записываются в несколько слов, с ошибками и т.д. Надо придумать, че с этим сделать
# Как идея -- попробовать посчитать встречаемость слов (может быть, до и после стемминга?)

# %%
tags_list = list(map(lambda x: x.split(), list(all_tags)))
words = []
for element in tags_list:
    words += element

# %%
unique, counts = np.unique(np.array(words), return_counts=True)
word_counts = dict(zip(unique, counts))

# %% [markdown]
# Возможно, время выставления также стоит учитывать, т.к. тогда мы сможем каким-то образом учитывать изменение в предпочтениях пользователя. Хотя, с другой стороны, для mvp нам это явно не поможет (это скорее улучшение для существующих пользователей). В общем, пока выкинем, потом придумаем
